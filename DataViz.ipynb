# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm

pd.options.display.max_rows = 999
pd.options.display.max_columns = 999

# %%
data1 = pd.read_csv("merged.csv")

# %%
data1.dtypes
# Out:
# Country                           object
# Economy (GDP per Capita)         float64
# Family                           float64
# Freedom                          float64
# Generosity                       float64
# Happiness Rank                     int64
# Happiness Score                  float64
# Health (Life Expectancy)         float64
# Region                            object
# Trust (Government Corruption)    float64
# Year                               int64
# dtype: object

# %%
data1.isna().sum()
# Out:
# Country                          0
# Economy (GDP per Capita)         0
# Family                           0
# Freedom                          0
# Generosity                       0
# Happiness Rank                   0
# Happiness Score                  0
# Health (Life Expectancy)         0
# Region                           0
# Trust (Government Corruption)    1
# Year                             0
# dtype: int64

# %%
data1.columns
# Out:
# Index(['Country', 'Economy (GDP per Capita)', 'Family', 'Freedom',
#        'Generosity', 'Happiness Rank', 'Happiness Score',
#        'Health (Life Expectancy)', 'Region', 'Trust (Government Corruption)',
#        'Year'],
#       dtype='object')

# %%
data1[data1.Country == "Gambia"].head()
# Out:
#     Country  Economy (GDP per Capita)  Family  Freedom  Generosity  \
# 745  Gambia                     0.308   0.939    0.382       0.269
#
#      Happiness Rank  Happiness Score  Health (Life Expectancy)  \
# 745             120            4.516                     0.428
#
#                  Region  Trust (Government Corruption)  Year
# 745  Sub-Saharan Africa                          0.167  2019

# %%
sns.relplot(x="Year",y="Happiness Score",hue="Happiness Score", data=data1)

# %%
sns.lineplot(data=data1,
             x="Year",
             y="Freedom").set_title("Happiness by Freedom");

# %%
sns.stripplot(data=data1,
             y="Year",x="Happiness Score")

# %%
sns.swarmplot(data=data1,
             y="Happiness Score",x="Freedom")

# %%
sns.barplot(data=(data1.loc[data1["Region"] == "North America"]),
             y="Happiness Score",x="Year")

# %%
sns.pointplot(data=data1,
             y="Happiness Score",x="Freedom")

# %%
sns.boxplot(data=data1,
             y="Happiness Score",x="Freedom")

# %%
sns.violinplot(data=data1,
             y="Happiness Score",x="Freedom")
